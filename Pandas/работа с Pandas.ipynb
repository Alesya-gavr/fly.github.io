# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv', sep=',')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(doc.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc.Age.mean()
doc.ShortPassing.std()
# Out:
# 14.740435689517149

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc[doc.Position=='GK'].count()
# Out:
# Unnamed: 0         1641
# Name               1641
# Age                1641
# Nationality        1641
# Club               1641
# Value              1641
# Wage               1641
# Position           1641
# Crossing           1641
# Finishing          1641
# HeadingAccuracy    1641
# ShortPassing       1641
# Volleys            1641
# Dribbling          1641
# Curve              1641
# FKAccuracy         1641
# LongPassing        1641
# BallControl        1641
# Acceleration       1641
# SprintSpeed        1641
# Agility            1641
# Reactions          1641
# Balance            1641
# ShotPower          1641
# Jumping            1641
# Stamina            1641
# Strength           1641
# LongShots          1641
# Aggression         1641
# Interceptions      1641
# Positioning        1641
# Vision             1641
# Penalties          1641
# Composure          1641
# Marking            1641
# StandingTackle     1641
# SlidingTackle      1641
# GKDiving           1641
# ...

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv', sep=',')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
print(df.baz)
# Out:
# 0     2
# 1     3
# 2     4
# 3     5
# 4     6
# 5     7
# 6     8
# 7     9
# 8    10
# 9    11
# Name: baz, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
players[players.HeadingAccuracy>50].Age.mean()
# Out:
# 25.58771113179944

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
players[((players.Composure.max())&(players.Reactions.max()))<].Age.min()
# Out:
#   File "<ipython-input-21-b27c63569f13>", line 3
#     players[((players.Composure.max())&(players.Reactions.max()))<].Age.min()
#                                                                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
players[players.Wage==565000].Position
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
players[(players.Value>players.Value.mean())&(players.max())].Nationality
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Series([], Name: Nationality, dtype: object)

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
f=players.head(5)
print(f)
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
react_old=players[players.Age.max()==players.Age].Reactions.mean()
react_young=players[players.Age.min()==players.Age].Reactions.mean()
diff=react_old-react_young
diff
# Out:
# 22.642857142857146

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
plr=players[players.Value>players.Value.mean()]
plr.describe(include=['object'])
# Out:
#                 Name Nationality       Club Position
# count           1747        1747       1747     1747
# unique          1558          98        447       27
# top     J. Rodríguez       Spain  Liverpool       ST
# freq               9         211         17      214

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
g1=players[(players.Position=='GK')&(players.GKReflexes==players.GKReflexes.max())].Wage.mean()
g2=players[players.GKHandling==players.GKHandling.max()].Wage.mean()
g1/g2
# Out:
# 2.765957446808511

# %%
import pandas as panda
players=pd.read_csv('data_sf.csv')
agr_max=players[players.Aggression==players.Aggression.max()].ShotPower.mean()
agr_min=players[players.Aggression==players.Aggression.min()].ShotPower.mean()
agr_max/agr_min
# Out:
# 2.076923076923077

# %%
import pandas as panda
players=pd.read_csv('data_sf.csv')
number=players[players.Value>players.Value.mean()].Position.count()
country=players[Position.count()==number]
# Out:
# 1747

# %%
import pandas as panda
players=pd.read_csv('data_sf.csv')
players[(players.Composure>players.Composure.max()*0.9)&(players.Reactions>players.Reactions.max()*0.9)].Age.min()
# Out:
# 24

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
s=players['Wage'].value_counts(bins=4)
s
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
small_pl = players[players.columns[0:7]].head(25)

s = small_pl['Wage'].value_counts(bins=4)

small_pl.loc[(small_pl['Wage'] > s.index[3].left) & (small_pl['Wage'] <= s.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
s=players['FKAccuracy'].value_counts(bins=4,normalize=True)
s
# Out:
# (25.75, 48.5]     0.521439
# (48.5, 71.25]     0.262697
# (2.908, 25.75]    0.180507
# (71.25, 94.0]     0.035357
# Name: FKAccuracy, dtype: float64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
s=players['Nationality'].unique()
len(s)
# Out:
# 156

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
s=players['Nationality'].value_counts()
df=s.reset_index()
df.columns = ['Nationality','Players Count']
df
# Out:
#      Nationality  Players Count
# 0        England           1368
# 1        Germany            919
# 2          Spain            671
# 3         France            614
# 4      Argentina            574
# ..           ...            ...
# 151      Andorra              1
# 152    Palestine              1
# 153  Puerto Rico              1
# 154       Belize              1
# 155     St Lucia              1
#
# [156 rows x 2 columns]

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
spain=players[players.Nationality=='Spain']
salary=spain['Wage'].value_counts(bins=4,normalize=True)
salary
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
club=players[players.Club=='Manchester United']
country=club['Nationality'].nunique()
country
# Out:
# 13

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
men=players[(players.Nationality=='Brazil')&(players.Club=='Juventus')]
men
# Out:
#     Unnamed: 0           Name  Age Nationality      Club     Value    Wage  \
# 64          64    Alex Sandro   27      Brazil  Juventus  36500000  160000
# 65          65  Douglas Costa   27      Brazil  Juventus  46500000  175000
#
#    Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 64       LB        84         55  ...         60         82       81
# 65       LM        84         67  ...         77         84       45
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 64              84             84         7           7          9
# 65              38             34        13          15          9
#
#     GKPositioning  GKReflexes
# 64             12           5
# 65             12           5
#
# [2 rows x 42 columns]

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
clubs=players[(players.Club=='Nagoya Grampus')|(players.Club=='Club Atlético Huracán')|(players.Club=='LA Galaxy')]
age=clubs[clubs.Age>35]
c=age['Club'].value_counts()
c
# Out:
# Club Atlético Huracán    4
# Nagoya Grampus           3
# LA Galaxy                2
# Name: Club, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
arg=players[players.Nationality=='Argentina']
age=arg['Age'].value_counts(bins=4)
age
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
spain=players[(players.Nationality=='Spain')]
age=spain['Age'].value_counts(normalize=True)
age
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
salary=players.groupby(['Club']).sum()
salary.loc['Örebro SK']
# Out:
# Unnamed: 0          224465
# Age                    622
# Value              8465000
# Wage                 36000
# Crossing              1114
# Finishing              974
# HeadingAccuracy       1149
# ShortPassing          1311
# Volleys                965
# Dribbling             1270
# Curve                 1147
# FKAccuracy             910
# LongPassing           1146
# BallControl           1318
# Acceleration          1699
# SprintSpeed           1638
# Agility               1639
# Reactions             1429
# Balance               1674
# ShotPower             1165
# Jumping               1715
# Stamina               1650
# Strength              1604
# LongShots             1003
# Aggression            1352
# Interceptions         1031
# Positioning           1048
# Vision                1227
# Penalties             1066
# Composure             1393
# Marking               1112
# StandingTackle        1045
# SlidingTackle         1008
# GKDiving               412
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
salary=players.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
salary
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
#                       ...
# AEK Athens             11000
# Shakhtar Donetsk       10000
# PAOK                   10000
# Olympiacos CFP          8000
# Dinamo Zagreb           7000
# Name: Wage, Length: 650, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pos=players.groupby(['Position'])['Wage'].sum()
five=pos.loc[pos>5000000]
five
# Out:
# Position
# CAM     5500000
# CB      7476000
# CM      6194000
# GK      8784000
# LB      6096000
# LM      5440000
# RB      5034000
# RM      5098000
# ST     11873000
# Name: Wage, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
age=players.groupby(['Club','Nationality'])['Age'].mean()
rm=age.loc['Real Madrid']
rm
# Out:
# Nationality
# Belgium               26.000000
# Brazil                28.000000
# Costa Rica            31.000000
# Croatia               32.000000
# Dominican Republic    24.000000
# France                25.000000
# Germany               28.000000
# Spain                 22.454545
# Wales                 28.000000
# Name: Age, dtype: float64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pos=players.groupby(['Position'])['Value', 'Wage'].mean()
pos
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                  Value           Wage
# Position
# CAM       2.963199e+06    8688.783570
# CB        1.321251e+06    5328.581611
# CDM       1.658900e+06    7121.562952
# CF        1.848627e+06    4862.745098
# CM        1.617465e+06    5805.060918
# GK        1.502502e+06    5352.833638
# LAM       1.324583e+07   61000.000000
# LB        1.429032e+06    6083.832335
# LCB       2.636516e+06    9753.056235
# LCM       4.318090e+06   13497.854077
# LDM       3.369459e+06   10243.243243
# LF        2.736250e+07   75125.000000
# LM        2.466174e+06    7472.527473
# LS        5.848430e+06   15421.487603
# LW        3.603099e+06   12169.421488
# LWB       1.931333e+06    5783.333333
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
par=players.groupby(['Club'])['Wage'].agg(['mean', 'median'])
r=par.loc[par['mean']==par['median']]
r.sort_values(['mean'],ascending=False)
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# Sunderland               4000.0    4000
# CD Feirense              4000.0    4000
# 1. FC Magdeburg          4000.0    4000
# Northampton Town         2500.0    2500
# Stade Brestois 29        2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Pohang Steelers          2000.0    2000
# AJ Auxerre               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Philadelphia Union       2000.0    2000
# Kashiwa Reysol           2000.0    2000
# CD Tondela               2000.0    2000
# Benevento                2000.0    2000
# FC Metz                  1500.0    1500
# PAOK                     1000.0    1000
# Orlando Pirates          1000.0    1000
# Panathinaikos FC         1000.0    1000
# Patriotas Boyacá FC      1000.0    1000
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
chelsea=players[players['Club']=='Chelsea']
salary=chelsea.groupby(['Club'])['Wage'].sum()
salary
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
nat_age=players[(players['Nationality']=='Argentina')&(players['Age']==30)]
max_sal=nat_age.groupby(['Nationality'])['Wage'].min()
max_sal
# Out:
# Nationality
# Argentina    1000
# Name: Wage, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
argbarc=players[(players['Club']=='FC Barcelona')&(players['Nationality']=='Argentina')]
st=argbarc['Strength']
bl=argbarc['Balance']
st, bl
# Out:
# (0    59
#  Name: Strength, dtype: int64,
#  0    95
#  Name: Balance, dtype: int64)

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.loc[players['Club'].isin(['FC Barcelona','Real Madrid', 'Juventus'])].pivot_table(values=['Wage'],
      index=['Nationality'],
      columns=['Club'],
      aggfunc='mean')
pivot
# Out:
#                              Wage
# Club                 FC Barcelona  Juventus    Real Madrid
# Nationality
# Argentina           565000.000000  205000.0            NaN
# Belgium             110000.000000       NaN  240000.000000
# Bosnia Herzegovina            NaN  180000.0            NaN
# Brazil              232500.000000  167500.0  285000.000000
# Chile               205000.000000       NaN            NaN
# Costa Rica                    NaN       NaN  195000.000000
# Croatia             260000.000000  160000.0  420000.000000
# Dominican Republic            NaN       NaN  140000.000000
# France              165000.000000  145000.0  153000.000000
# Germany             240000.000000  160000.0  355000.000000
# Italy                         NaN  115000.0            NaN
# Morocco                       NaN  160000.0            NaN
# Netherlands         135000.000000       NaN            NaN
# Poland                        NaN  125000.0            NaN
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values=['Wage'],
    index=['Position'],
    columns=['Club'],
    aggfunc='max')
pivot
# Out:
#                          Wage                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# CAM                       NaN                5000.0                  NaN
# CB                     5000.0                7000.0               1000.0
# CDM                    5000.0                   NaN               1000.0
# CF                        NaN                   NaN                  NaN
# CM                     4000.0                1000.0                  NaN
# GK                     5000.0                4000.0               1000.0
# LAM                       NaN                   NaN                  NaN
# LB                     6000.0                6000.0               2000.0
# LCB                       NaN                6000.0               2000.0
# LCM                       NaN                   NaN                  NaN
# LDM                    6000.0                   NaN                  NaN
# ...

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values=['Name'],
                   index=['Position'],
                   columns=['Club'],
                   aggfunc='count',
                   fill_value=0)
vratary=(pivot.loc['GK']).mean()
vratary
# Out:
# 2.5246153846153847

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values=['Name'],
                   index=['Position'],
                   columns=['Club'],
                   aggfunc='count',
                   fill_value=0)
clubs=(pivot.loc['CM'].value_counts())
clubs
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values='Wage',
                         index=['Nationality'],
                         columns=['Club'],
                         aggfunc='mean')
pivot.loc['Russia','AS Monaco']
# Out:
# 61000.0

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values=['SprintSpeed'],
                   index=['Club'],
                   columns=['Position'],
                   aggfunc='mean',
                   fill_value=0)
pivot['SprintSpeed'].max().sort_values(ascending=False)
# Out:
# Position
# RS     94.0
# RM     94.0
# LM     94.0
# LS     93.0
# RB     93.0
# LB     93.0
# CF     91.0
# LW     91.0
# ST     91.0
# RDM    91.0
# RW     91.0
# RCM    90.0
# CAM    89.0
# LF     88.0
# RCB    88.0
# LCB    88.0
# RWB    86.0
# RF     86.0
# CM     86.0
# LWB    86.0
# LAM    85.0
# LCM    84.0
# CDM    83.0
# LDM    79.0
# RAM    78.0
# CB     78.0
# GK     62.0
# dtype: float64

# %%
import pandas as pd
players=pd.read_csv('data_sf.csv')
pivot=players.pivot_table(values=['SprintSpeed'],
                   index=['Position'],
                   columns=['Club'],
                   aggfunc='mean',
                   fill_value=0)
pivot.loc['ST'].sort_values(ascending=False)
# Out:
#              Club
# SprintSpeed  Vitória                  91.000000
#              Sydney FC                88.000000
#              CD Lugo                  87.000000
#              Brøndby IF               84.666667
#              Leicester City           84.500000
#                                         ...
#              Málaga CF                 0.000000
#              PFC CSKA Moscow           0.000000
#              Stade Rennais FC          0.000000
#              Standard de Liège         0.000000
#              Sporting de Charleroi     0.000000
# Name: ST, Length: 650, dtype: float64

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc[doc.Wage==doc.Wage.max()]
# Out:
#    Unnamed: 0      Name  Age Nationality          Club      Value    Wage  \
# 0           0  L. Messi   31   Argentina  FC Barcelona  110500000  565000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
#
#    GKPositioning  GKReflexes
# 0             14           8
#
# [1 rows x 42 columns]

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc[(doc.Composure>doc.Composure.max()*0.9)&(doc.Reactions>doc.Reactions.max()*0.9)].Age.min()
# Out:
# 24

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
value=doc[doc.Value>doc.Value.mean()]
value.describe(include='object')
# Out:
#                 Name Nationality          Club Position
# count           1747        1747          1747     1747
# unique          1558          98           447       27
# top     J. Rodríguez       Spain  FC Barcelona       ST
# freq               9         211            17      214

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
club=doc.Position.value_counts(normalize=True)
club.loc[club>0.1]
# Out:
# GK    0.127239
# ST    0.117237
# CB    0.108785
# Name: Position, dtype: float64

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
wage=doc.Wage.value_counts(bins=4)
doc.loc[(doc.Wage>wage.index[3].left)&(doc.Wage<=wage.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage  \
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
# 7       RS        77         93  ...         85         85       62
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 7              45             38        27          25         31
#
#    GKPositioning  GKReflexes
# 0             14           8
# 7             33          37
#
# [2 rows x 42 columns]

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc[doc.Club=='Manchester United'].Nationality.nunique()
# Out:
# 13

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
doc[doc.Age>35].Club.value_counts()
# Out:
# Club Atlético Huracán         4
# Hokkaido Consadole Sapporo    4
# Club Atlético Talleres        3
# Nagoya Grampus                3
# Hammarby IF                   3
#                              ..
# AJ Auxerre                    1
# Beijing Renhe FC              1
# Djurgårdens IF                1
# Piast Gliwice                 1
# Shimizu S-Pulse               1
# Name: Club, Length: 212, dtype: int64

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
pos=doc.groupby(['Position'])['Wage'].sum()
pos.loc[pos>5000000]
# Out:
# Position
# CAM     5500000
# CB      7476000
# CM      6194000
# GK      8784000
# LB      6096000
# LM      5440000
# RB      5034000
# RM      5098000
# ST     11873000
# Name: Wage, dtype: int64

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
pivot=doc.pivot_table(values='Name',
               index='Position',
               columns='Club',
               aggfunc='count',
               fill_value=0)
pivot.loc['GK'].mean()
# Out:
# 2.5246153846153847

# %%
import pandas as pd
doc=pd.read_csv('data_sf.csv')
pivot=doc.pivot_table(values='Wage',
                     index='Nationality',
                     columns='Club',
                     aggfunc='mean',
                     fill_value=0)
pivot.loc['Russia']['AS Monaco']
# Out:
# 61000.0
